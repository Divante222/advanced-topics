# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from pydataset import data

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# the imports

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = data('mpg')

# %%
df.trans = np.where(df.trans.str.startswith('auto'), 'auto', 'manual')

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl   trans drv  cty  hwy fl    class
# 1           audi      a4    1.8  1999    4    auto   f   18   29  p  compact
# 2           audi      a4    1.8  1999    4  manual   f   21   29  p  compact
# 3           audi      a4    2.0  2008    4  manual   f   20   31  p  compact
# 4           audi      a4    2.0  2008    4    auto   f   21   30  p  compact
# 5           audi      a4    2.8  1999    6    auto   f   16   26  p  compact
# ..           ...     ...    ...   ...  ...     ...  ..  ...  ... ..      ...
# 230   volkswagen  passat    2.0  2008    4    auto   f   19   28  p  midsize
# 231   volkswagen  passat    2.0  2008    4  manual   f   21   29  p  midsize
# 232   volkswagen  passat    2.8  1999    6    auto   f   16   26  p  midsize
# 233   volkswagen  passat    2.8  1999    6  manual   f   18   26  p  midsize
# 234   volkswagen  passat    3.6  2008    6    auto   f   17   26  p  midsize
#
# [234 rows x 11 columns]

# %%
X = df[['displ', 'year', 'cyl', 'cty', 'hwy']]

# %%
y = df.trans

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    random_state=123)

# %%
tree = DecisionTreeClassifier(max_depth=4, random_state=123)

# %%
cross_val_score(tree, X_train, y_train, cv=5)
# Out:
# array([0.57142857, 0.65714286, 0.65714286, 0.57142857, 0.6       ])

# %%
# Out:
# 0.6114285714285714

# %%
dt = DecisionTreeClassifier(random_state=123)
parameters = {
    'max_depth':range(1,21),
    'min_samples_leaf':range(1,11),
    'criterion': ["gini", "entropy", "log_loss"]
}

# %%
grid = GridSearchCV(dt, parameters, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=123),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': range(1, 21),
#                          'min_samples_leaf': range(1, 11)})

# %%
len(grid.cv_results_['params'])
# Out:
# 600

# %%
grid.cv_results_['params']
# Out:
# [{'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 10},
#  {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 4},
#  {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 5},
#  {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 6},
#  {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 7},
#  {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 8},
#  {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 9},
#  {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 10},
#  {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 4},
#  {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 5},
#  {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 6},
#  {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 7},
#  {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 8},
#  {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 9},
#  {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 1, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 1, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 1, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 1, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 1, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 1, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 1, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 1, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 1, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 1, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 2, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 2, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 2, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 2, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 2, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 2, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 2, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 2, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 2, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 2, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 3, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 3, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 3, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 3, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 3, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 3, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 3, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 3, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 3, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 3, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 4, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 4, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 4, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 4, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 4, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 4, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 4, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 4, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 4, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 4, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 5, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 5, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 5, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 5, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 5, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 5, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 5, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 5, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 5, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 5, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 6, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 6, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 6, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 6, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 6, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 6, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 6, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 6, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 6, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 6, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 7, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 7, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 7, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 7, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 7, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 7, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 7, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 7, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 7, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 7, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 8, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 8, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 8, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 8, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 8, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 8, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 8, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 8, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 8, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 8, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 9, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 9, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 9, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 9, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 9, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 9, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 9, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 9, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 9, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 9, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 11, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 11, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 11, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 11, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 11, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 11, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 11, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 11, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 11, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 11, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 12, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 12, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 12, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 12, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 12, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 12, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 12, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 12, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 12, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 12, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 13, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 13, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 13, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 13, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 13, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 13, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 13, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 13, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 13, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 13, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 14, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 14, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 14, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 14, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 14, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 14, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 14, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 14, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 14, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 14, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 16, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 16, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 16, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 16, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 16, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 16, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 16, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 16, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 16, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 16, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 18, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 18, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 18, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 18, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 18, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 18, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 18, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 18, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 18, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 18, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 19, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 19, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 19, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 19, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 19, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 19, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 19, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 19, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 19, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 19, 'min_samples_leaf': 10},
#  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_leaf': 1},
#  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_leaf': 2},
#  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_leaf': 3},
#  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_leaf': 4},
#  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_leaf': 5},
#  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_leaf': 6},
#  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_leaf': 7},
#  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_leaf': 8},
#  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_leaf': 9},
#  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_leaf': 10}]

# %%
lr = LogisticRegression(random_state = 123)
lr
# Out:
# LogisticRegression(random_state=123)

# %%
X = df[['displ', 'year', 'cyl', 'cty', 'hwy']]
y = df.trans

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    random_state=123)
parameters_DTree = {
    'max_depth':range(1,21),
    'min_samples_leaf':range(1,11),
    'criterion': ["gini", "entropy", "log_loss"]
}

parameters_rf = {'max_depth':range(1,21),
                "min_samples_leaf":range(1,21),
                "criterion": ['gini', 'entropy', 'log_loss']
                }

parameters_knn = {
    'n_neighbors':range(1,21),
    'weights':['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'leaf_size':range(1,31),
    'p': range(1,5)
    
}

parameters_lr = {
    'penalty':['l1', 'l2', 'elasticnet'],
    'dual':[True, False], 
    'C':range(1,21),
    
}


dt = DecisionTreeClassifier(random_state=123)
rf = RandomForestClassifier(random_state=123)
knn = KNeighborsClassifier()
lr = LogisticRegression(random_state = 123)

the_parameters = [parameters_DTree, parameters_rf, parameters_knn, parameters_lr]
best_df = pd.Dataframe()
models = ['DecisionTreeClassifier','RandomForestClassifier','KNeighborsClassifier','LogisticRegression',]
for number, tree in enumerate([dt, rf, knn, lr]):
    grid = GridSearchCV(tree, the_parameters[number], cv=5)
    grid.fit(X_train, y_train)


    for p, score in zip(grid.cv_results_['params'], grid.cv_results_['mean_test_score']):
        p['score'] = score
        p['model'] = models[number]

    new_df = pd.concat(pd.DataFrame(grid.cv_results_['params']).sort_values('score', ascending=False))
    best_df = pd.concat([best_df, new_df.head(1)])
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 500 fits failed out of a total of 600.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 100 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 59, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only dual=False, got dual=True
#
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan 0.6               nan
#         nan        nan        nan        nan 0.59428571        nan
#         nan        nan        nan        nan 0.6               nan
#         nan        nan        nan        nan 0.59428571        nan
#         nan        nan        nan        nan 0.6               nan
#         nan        nan        nan        nan 0.61142857        nan
#         nan        nan        nan        nan 0.61142857        nan
#         nan        nan        nan        nan 0.59428571        nan
#         nan        nan        nan        nan 0.59428571        nan
#         nan        nan        nan        nan 0.59428571        nan
#         nan        nan        nan        nan 0.59428571        nan
#         nan        nan        nan        nan 0.59428571        nan
#         nan        nan        nan        nan 0.58285714        nan
#         nan        nan        nan        nan 0.59428571        nan
#         nan        nan        nan        nan 0.59428571        nan
#         nan        nan        nan        nan 0.59428571        nan
#         nan        nan        nan        nan 0.58285714        nan
#         nan        nan        nan        nan 0.58285714        nan
#         nan        nan        nan        nan 0.59428571        nan
#         nan        nan        nan        nan 0.58285714        nan]
#   warnings.warn(
#       C   dual     penalty     score
# 34    6  False          l2  0.611429
# 40    7  False          l2  0.611429
# 4     1  False          l2  0.600000
# 16    3  False          l2  0.600000
# 28    5  False          l2  0.600000
# 70   12  False          l2  0.594286
# 112  19  False          l2  0.594286
# 94   16  False          l2  0.594286
# 88   15  False          l2  0.594286
# 82   14  False          l2  0.594286
# 64   11  False          l2  0.594286
# 10    2  False          l2  0.594286
# 58   10  False          l2  0.594286
# 52    9  False          l2  0.594286
# 46    8  False          l2  0.594286
# 22    4  False          l2  0.594286
# 76   13  False          l2  0.582857
# 100  17  False          l2  0.582857
# 106  18  False          l2  0.582857
# 118  20  False          l2  0.582857
# 0     1   True          l1       NaN
# 1     1   True          l2       NaN
# 2     1   True  elasticnet       NaN
# 3     1  False          l1       NaN
# 5     1  False  elasticnet       NaN
# 6     2   True          l1       NaN
# 7     2   True          l2       NaN
# 8     2   True  elasticnet       NaN
# 9     2  False          l1       NaN
# 11    2  False  elasticnet       NaN
# 12    3   True          l1       NaN
# 13    3   True          l2       NaN
# 14    3   True  elasticnet       NaN
# 15    3  False          l1       NaN
# 17    3  False  elasticnet       NaN
# 18    4   True          l1       NaN
# 19    4   True          l2       NaN
# 20    4   True  elasticnet       NaN
# 21    4  False          l1       NaN
# 23    4  False  elasticnet       NaN
# 24    5   True          l1       NaN
# 25    5   True          l2       NaN
# 26    5   True  elasticnet       NaN
# 27    5  False          l1       NaN
# 29    5  False  elasticnet       NaN
# 30    6   True          l1       NaN
# 31    6   True          l2       NaN
# 32    6   True  elasticnet       NaN
# 33    6  False          l1       NaN
# 35    6  False  elasticnet       NaN
# 36    7   True          l1       NaN
# 37    7   True          l2       NaN
# 38    7   True  elasticnet       NaN
# 39    7  False          l1       NaN
# 41    7  False  elasticnet       NaN
# 42    8   True          l1       NaN
# 43    8   True          l2       NaN
# 44    8   True  elasticnet       NaN
# 45    8  False          l1       NaN
# 47    8  False  elasticnet       NaN
# 48    9   True          l1       NaN
# 49    9   True          l2       NaN
# 50    9   True  elasticnet       NaN
# 51    9  False          l1       NaN
# 53    9  False  elasticnet       NaN
# 54   10   True          l1       NaN
# 55   10   True          l2       NaN
# 56   10   True  elasticnet       NaN
# 57   10  False          l1       NaN
# 59   10  False  elasticnet       NaN
# 60   11   True          l1       NaN
# 61   11   True          l2       NaN
# 62   11   True  elasticnet       NaN
# 63   11  False          l1       NaN
# 65   11  False  elasticnet       NaN
# 66   12   True          l1       NaN
# 67   12   True          l2       NaN
# 68   12   True  elasticnet       NaN
# 69   12  False          l1       NaN
# 71   12  False  elasticnet       NaN
# 72   13   True          l1       NaN
# 73   13   True          l2       NaN
# 74   13   True  elasticnet       NaN
# 75   13  False          l1       NaN
# 77   13  False  elasticnet       NaN
# 78   14   True          l1       NaN
# 79   14   True          l2       NaN
# 80   14   True  elasticnet       NaN
# 81   14  False          l1       NaN
# 83   14  False  elasticnet       NaN
# 84   15   True          l1       NaN
# 85   15   True          l2       NaN
# 86   15   True  elasticnet       NaN
# 87   15  False          l1       NaN
# 89   15  False  elasticnet       NaN
# 90   16   True          l1       NaN
# 91   16   True          l2       NaN
# 92   16   True  elasticnet       NaN
# 93   16  False          l1       NaN
# 95   16  False  elasticnet       NaN
# 96   17   True          l1       NaN
# 97   17   True          l2       NaN
# 98   17   True  elasticnet       NaN
# 99   17  False          l1       NaN
# 101  17  False  elasticnet       NaN
# 102  18   True          l1       NaN
# 103  18   True          l2       NaN
# 104  18   True  elasticnet       NaN
# 105  18  False          l1       NaN
# 107  18  False  elasticnet       NaN
# 108  19   True          l1       NaN
# 109  19   True          l2       NaN
# 110  19   True  elasticnet       NaN
# 111  19  False          l1       NaN
# 113  19  False  elasticnet       NaN
# 114  20   True          l1       NaN
# 115  20   True          l2       NaN
# 116  20   True  elasticnet       NaN
# 117  20  False          l1       NaN
# 119  20  False  elasticnet       NaN

# %%
df3 = pd.DataFrame([['c', 3, 'cat'], ['d', 4, 'dog']])
df2 = pd.DataFrame([['d', 4, 'rat'], ['q', 99, 'pig']])
pd.concat([df3, df2.head(1)])
# Out:
#    0  1    2
# 0  c  3  cat
# 1  d  4  dog
# 0  d  4  rat
